# %%
# !git clone https://github.com/RUCAIBox/NCL
# Out:
# Cloning into 'NCL'...
# remote: Enumerating objects: 38, done.
# remote: Counting objects: 100% (38/38), done.
# remote: Compressing objects: 100% (33/33), done.
# remote: Total 38 (delta 17), reused 18 (delta 4), pack-reused 0
# Receiving objects: 100% (38/38), 278.65 KiB | 2.76 MiB/s, done.
# Resolving deltas: 100% (17/17), done.

# %%
# %cd NCL
# Out:
# /content/NCL

# %%
# !pip install recbole

# %%
# !pip install faiss-gpu

# %%
# !python main.py --dataset ml-1m
# Out:
# /content/NCL/main.py:65: SyntaxWarning: "is not" with a literal. Did you mean "!="?
#   if args.config is not '':
# 2023-11-02 06:28:22.926450: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-11-02 06:28:22.926521: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-11-02 06:28:22.926623: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-11-02 06:28:22.937757: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# ...
